# %%
import pandas as pd
import numpy as np

# %%
filenames = ['https://s3.amazonaws.com/pp-projects-static/congress/assets/staffers/2009Q3-house-disburse-detail.csv',\
             'https://s3.amazonaws.com/pp-projects-static/congress/assets/staffers/2015Q2-house-disburse-detail-updated.csv']

# %%
df=[]

# %%
for f in filenames:
    df.append(pd.read_csv(f))

# %%
df
# Out:
# [       BIOGUIDE_ID                     OFFICE QUARTER  \
#  0              NaN             COMMUNICATIONS  2009Q3
#  1              NaN             COMMUNICATIONS  2009Q3
#  2              NaN             COMMUNICATIONS  2009Q3
#  3              NaN             COMMUNICATIONS  2009Q3
#  4              NaN             COMMUNICATIONS  2009Q3
#  5              NaN             COMMUNICATIONS  2009Q3
#  6              NaN             COMMUNICATIONS  2009Q3
#  7              NaN             COMMUNICATIONS  2009Q3
#  8              NaN             COMMUNICATIONS  2009Q3
#  9              NaN             COMMUNICATIONS  2009Q3
#  10             NaN             COMMUNICATIONS  2009Q3
#  11             NaN             COMMUNICATIONS  2009Q3
#  12             NaN             COMMUNICATIONS  2009Q3
#  13             NaN             COMMUNICATIONS  2009Q3
#  14             NaN             COMMUNICATIONS  2009Q3
#  15             NaN             COMMUNICATIONS  2009Q3
# ...

# %%
data2015Q2=pd.read_csv('https://s3.amazonaws.com/pp-projects-static/congress/assets/staffers/2015Q2-house-disburse-detail-updated.csv')

# %%
data2015Q2
# Out:
#       BIOGUIDE_ID                   OFFICE QUARTER                CATEGORY  \
# 0             NaN    OFFICE OF THE SPEAKER  2015Q2      PERSONNEL BENEFITS
# 1             NaN    OFFICE OF THE SPEAKER  2015Q2      PERSONNEL BENEFITS
# 2             NaN    OFFICE OF THE SPEAKER  2015Q2      PERSONNEL BENEFITS
# 3             NaN    OFFICE OF THE SPEAKER  2015Q2  PERSONNEL COMPENSATION
# 4             NaN    OFFICE OF THE SPEAKER  2015Q2  PERSONNEL COMPENSATION
# 5             NaN    OFFICE OF THE SPEAKER  2015Q2  PERSONNEL COMPENSATION
# 6             NaN    OFFICE OF THE SPEAKER  2015Q2  PERSONNEL COMPENSATION
# 7             NaN    OFFICE OF THE SPEAKER  2015Q2  PERSONNEL COMPENSATION
# 8             NaN    OFFICE OF THE SPEAKER  2015Q2  PERSONNEL COMPENSATION
# 9             NaN    OFFICE OF THE SPEAKER  2015Q2  PERSONNEL COMPENSATION
# 10            NaN    OFFICE OF THE SPEAKER  2015Q2  PERSONNEL COMPENSATION
# ...

# %%
data2015Q2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 95493 entries, 0 to 95492
# Data columns (total 15 columns):
# BIOGUIDE_ID      22814 non-null object
# OFFICE           95493 non-null object
# QUARTER          95493 non-null object
# CATEGORY         95493 non-null object
# DATE             83641 non-null object
# PAYEE            82337 non-null object
# START DATE       95493 non-null object
# END DATE         95493 non-null object
# PURPOSE          95493 non-null object
# AMOUNT           95493 non-null object
# YEAR             95493 non-null object
# TRANSCODE        83641 non-null object
# TRANSCODELONG    83641 non-null object
# RECORDID         83641 non-null object
# RECIP (orig.)    82337 non-null object
# dtypes: object(15)
# memory usage: 10.9+ MB

# %%
data2015Q2.head()
# Out:
#   BIOGUIDE_ID                 OFFICE QUARTER                CATEGORY    DATE  \
# 0         NaN  OFFICE OF THE SPEAKER  2015Q2      PERSONNEL BENEFITS  15-Apr
# 1         NaN  OFFICE OF THE SPEAKER  2015Q2      PERSONNEL BENEFITS  14-May
# 2         NaN  OFFICE OF THE SPEAKER  2015Q2      PERSONNEL BENEFITS  15-Jun
# 3         NaN  OFFICE OF THE SPEAKER  2015Q2  PERSONNEL COMPENSATION     NaN
# 4         NaN  OFFICE OF THE SPEAKER  2015Q2  PERSONNEL COMPENSATION     NaN
#
#                 PAYEE START DATE END DATE                        PURPOSE  \
# 0  HON JOHN A BOEHNER     4/3/15   5/2/15  OFFICIAL EXPENSES FOR LEADERS
# 1  HON JOHN A BOEHNER     5/3/15   6/2/15  OFFICIAL EXPENSES FOR LEADERS
# 2  HON JOHN A BOEHNER     6/3/15   7/2/15  OFFICIAL EXPENSES FOR LEADERS
# 3    ANDREWS,THOMAS S     4/1/15  6/30/15    SPECIAL ASST TO THE SPEAKER
# 4      BAILEY,BRADLEY     4/1/15  6/30/15   ASSIST TO SPEAKER FOR POLICY
#
# ...

# %%
data2015Q2.dtypes
# Out:
# BIOGUIDE_ID      object
# OFFICE           object
# QUARTER          object
# CATEGORY         object
# DATE             object
# PAYEE            object
# START DATE       object
# END DATE         object
# PURPOSE          object
# AMOUNT           object
# YEAR             object
# TRANSCODE        object
# TRANSCODELONG    object
# RECORDID         object
# RECIP (orig.)    object
# dtype: object

# %%
data2015Q2.AMOUNT
# Out:
# 0         2,083.33
# 1         2,083.33
# 2         2,083.33
# 3        15,000.00
# 4        30,000.00
# 5        11,250.00
# 6        24,500.01
# 7        30,000.00
# 8        41,750.01
# 9        24,999.99
# 10       42,000.00
# 11       43,125.00
# 12       13,250.01
# 13       24,624.99
# 14       15,000.00
# 15        8,750.01
# 16        1,003.29
# 17       30,000.00
# 18       16,250.01
# 19        3,111.11
# 20       43,125.00
# 21       36,249.99
# 22        8,750.01
# 23        1,205.21
# 24       27,500.01
# 25       33,287.49
# 26        3,875.00
# 27          584.12
# 28       42,000.00
# 29        8,050.00
#            ...
# 95463          800
# 95464          800
# 95465          800
# 95466          800
# 95467          800
# 95468          800
# 95469          800
# 95470          800
# 95471          800
# 95472          800
# 95473          800
# 95474          800
# 95475          800
# 95476          800
# 95477          800
# 95478          800
# ...

# %%
data2015Q2.AMOUNT = data2015Q2.AMOUNT.str.replace(',','')

# %%
data2015Q2.AMOUNT = data2015Q2['AMOUNT'].astype(float)

# %%
data2015Q2.AMOUNT.sum()
# Out:
# 277430411.79

# %%
df.AMOUNT
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-77-8b459eaebfd6> in <module>()
# ----> 1 df.AMOUNT
#
# AttributeError: 'list' object has no attribute 'AMOUNT'

# %%
df['AMOUNT']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-78-0dc06812dd7d> in <module>()
# ----> 1 df['AMOUNT']
#
# TypeError: list indices must be integers or slices, not str

# %%
# Out:
# [       BIOGUIDE_ID                     OFFICE QUARTER  \
#  0              NaN             COMMUNICATIONS  2009Q3
#  1              NaN             COMMUNICATIONS  2009Q3
#  2              NaN             COMMUNICATIONS  2009Q3
#  3              NaN             COMMUNICATIONS  2009Q3
#  4              NaN             COMMUNICATIONS  2009Q3
#  5              NaN             COMMUNICATIONS  2009Q3
#  6              NaN             COMMUNICATIONS  2009Q3
#  7              NaN             COMMUNICATIONS  2009Q3
#  8              NaN             COMMUNICATIONS  2009Q3
#  9              NaN             COMMUNICATIONS  2009Q3
#  10             NaN             COMMUNICATIONS  2009Q3
#  11             NaN             COMMUNICATIONS  2009Q3
#  12             NaN             COMMUNICATIONS  2009Q3
#  13             NaN             COMMUNICATIONS  2009Q3
#  14             NaN             COMMUNICATIONS  2009Q3
#  15             NaN             COMMUNICATIONS  2009Q3
# ...
