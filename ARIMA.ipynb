# %%
import pandas_datareader.data as web
import datetime as dt
import numpy as np
import pandas as pd
import statsmodels.api as sm
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.style.use('ggplot')

# %%
start = dt.datetime(2015, 10, 25)
end = dt.datetime(2018,10, 25)

# %%
prices = web.DataReader('AAPL','iex',start,end)['close']
prices.index
# Out:
# Index(['2015-10-26', '2015-10-27', '2015-10-28', '2015-10-29', '2015-10-30',
#        '2015-11-02', '2015-11-03', '2015-11-04', '2015-11-05', '2015-11-06',
#        ...
#        '2018-10-12', '2018-10-15', '2018-10-16', '2018-10-17', '2018-10-18',
#        '2018-10-19', '2018-10-22', '2018-10-23', '2018-10-24', '2018-10-25'],
#       dtype='object', name='date', length=757)

# %%
lnprices = np.log(prices)
plt.plot(lnprices)
plt.show()
