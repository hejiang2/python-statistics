# %%
import pandas as pd
import numpy as np

# %%
data_2009Q3 = pd.read_csv('https://s3.amazonaws.com/pp-projects-static/congress/assets/staffers/2009Q3-house-disburse-detail.csv')

# %%
data_2009Q3.head()
# Out:
#   BIOGUIDE_ID          OFFICE QUARTER        CATEGORY  DATE  \
# 0         NaN  COMMUNICATIONS  2009Q3  OTHER SERVICES   NaN
# 1         NaN  COMMUNICATIONS  2009Q3  OTHER SERVICES   NaN
# 2         NaN  COMMUNICATIONS  2009Q3  OTHER SERVICES   NaN
# 3         NaN  COMMUNICATIONS  2009Q3  OTHER SERVICES   NaN
# 4         NaN  COMMUNICATIONS  2009Q3  OTHER SERVICES   NaN
#
#                                                PAYEE START DATE  END DATE  \
# 0  07Â­01   P2 OPR0900726A                    STR...   10/04/06  10/04/06
# 1  07Â­22   P2 OPR0900726B                       ...   10/04/06  10/04/06
# 2  08Â­06   P2 FSS0000575A                    THE...   07/18/06  07/18/06
# 3   08Â­25   P2 MFP0003163                     AVAYA   05/29/09  05/29/09
# 4  09Â­10   P2 OPR0900726C                    STR...   10/04/06  10/04/06
#
#                           PURPOSE     AMOUNT              YEAR  TRANSCODE  \
# 0  NON-TECHNOLOGY SERVICE CONTRCT  16,799.25  FISCAL YEAR 2009        NaN
# ...

# %% [markdown]
# data_2010Q1 = pd.read_csv('https://s3.amazonaws.com/pp-projects-static/congress/assets/staffers/2010Q1-house-disburse-detail.csv')

# %%
pwd
# Out:
# '/Users/fiona'

# %%
data_2009Q4 = pd.read_csv('https://s3.amazonaws.com/pp-projects-static/congress/assets/staffers/2009Q4-house-disburse-detail.csv')

# %%
data_2009 = pd.concat([data_2009Q3,data_2009Q4])

# %%
data_2009
# Out:
#        BIOGUIDE_ID                   OFFICE QUARTER                CATEGORY  \
# 0              NaN           COMMUNICATIONS  2009Q3          OTHER SERVICES
# 1              NaN           COMMUNICATIONS  2009Q3          OTHER SERVICES
# 2              NaN           COMMUNICATIONS  2009Q3          OTHER SERVICES
# 3              NaN           COMMUNICATIONS  2009Q3          OTHER SERVICES
# 4              NaN           COMMUNICATIONS  2009Q3          OTHER SERVICES
# 5              NaN           COMMUNICATIONS  2009Q3          OTHER SERVICES
# 6              NaN           COMMUNICATIONS  2009Q3          OTHER SERVICES
# 7              NaN           COMMUNICATIONS  2009Q3  SUPPLIES AND MATERIALS
# 8              NaN           COMMUNICATIONS  2009Q3  SUPPLIES AND MATERIALS
# 9              NaN           COMMUNICATIONS  2009Q3  SUPPLIES AND MATERIALS
# 10             NaN           COMMUNICATIONS  2009Q3               EQUIPMENT
# ...

# %%
sum_amount2009 = data_2009.AMOUNT.str.replace(',','').astype(float).sum()

# %%
sum_amount2009
# Out:
# 580566492.7999998

# %%
data_2010Q2 = pd.read_csv('https://s3.amazonaws.com/pp-projects-static/congress/assets/staffers/2010Q2-house-disburse-detail.csv')

# %%
data_2010Q3 = pd.read_csv('https://s3.amazonaws.com/pp-projects-static/congress/assets/staffers/2010Q3-house-disburse-detail.csv')

# %%
data_2010Q4 = pd.read_csv('https://s3.amazonaws.com/pp-projects-static/congress/assets/staffers/2010Q4-house-disburse-detail.csv')

# %%
data_2010Q4.head()
# Out:
#   BIOGUIDE_ID                 OFFICE QUARTER                CATEGORY DATE  \
# 0         NaN  OFFICE OF THE SPEAKER  2010Q4  PERSONNEL COMPENSATION  NaN
# 1         NaN  OFFICE OF THE SPEAKER  2010Q4  PERSONNEL COMPENSATION  NaN
# 2         NaN  OFFICE OF THE SPEAKER  2010Q4  PERSONNEL COMPENSATION  NaN
# 3         NaN  OFFICE OF THE SPEAKER  2010Q4  PERSONNEL COMPENSATION  NaN
# 4         NaN  OFFICE OF THE SPEAKER  2010Q4  PERSONNEL COMPENSATION  NaN
#
#             PAYEE START DATE  END DATE                         PURPOSE  \
# 0   DALY, BRENDAN   10/01/10  12/31/10         COMMUNICATIONS DIRECTOR
# 1  ELSHAMI,NADEEM   10/01/10  12/31/10  DEPUTY COMMUNICATIONS DIRECTOR
# 2    HARTZ, JERRY   10/01/10  12/31/10    DIRECTOR OF FLOOR OPERATIONS
# 3     ONEK,JOSEPH   10/01/10  12/31/10   SENIOR COUNSEL TO THE SPEAKER
# 4   ROSE,CHERYL P   10/01/10  10/31/10       DIR OF INTERGOV'T AFFAIRS
#
#       AMOUNT              YEAR TRANSCODE TRANSCODELONG RECORDID  \
# ...

# %%
data_2011Q1 = pd.read_csv('https://s3.amazonaws.com/pp-projects-static/congress/assets/staffers/2011Q1-house-disburse-detail.csv')

# %%
data_2011Q2 = pd.read_csv('https://s3.amazonaws.com/pp-projects-static/congress/assets/staffers/2011Q2-house-disburse-detail.csv')

# %%
data_2011Q3 = pd.read_csv('https://s3.amazonaws.com/pp-projects-static/congress/assets/staffers/2011Q3-house-disburse-detail.csv')

# %%
data_2011Q4 = pd.read_csv('https://s3.amazonaws.com/pp-projects-static/congress/assets/staffers/2011Q4-house-disburse-detail.csv')

# %%
data_2011= pd.concat([data_2011Q1,data_2011Q2,data_2011Q3,data_2011Q4])

# %%
data_2011
# Out:
#        BIOGUIDE_ID                 OFFICE QUARTER                CATEGORY  \
# 0              NaN  OFFICE OF THE SPEAKER  2011Q1  PERSONNEL COMPENSATION
# 1              NaN  OFFICE OF THE SPEAKER  2011Q1  PERSONNEL COMPENSATION
# 2              NaN  OFFICE OF THE SPEAKER  2011Q1  PERSONNEL COMPENSATION
# 3              NaN  OFFICE OF THE SPEAKER  2011Q1  PERSONNEL COMPENSATION
# 4              NaN  OFFICE OF THE SPEAKER  2011Q1  PERSONNEL COMPENSATION
# 5              NaN  OFFICE OF THE SPEAKER  2011Q1  PERSONNEL COMPENSATION
# 6              NaN  OFFICE OF THE SPEAKER  2011Q1  PERSONNEL COMPENSATION
# 7              NaN  OFFICE OF THE SPEAKER  2011Q1  PERSONNEL COMPENSATION
# 8              NaN  OFFICE OF THE SPEAKER  2011Q1  PERSONNEL COMPENSATION
# 9              NaN  OFFICE OF THE SPEAKER  2011Q1  PERSONNEL COMPENSATION
# 10             NaN  OFFICE OF THE SPEAKER  2011Q1  PERSONNEL COMPENSATION
# 11             NaN  OFFICE OF THE SPEAKER  2011Q1  PERSONNEL COMPENSATION
# ...

# %%
data_2012Q1 = pd.read_csv('https://s3.amazonaws.com/pp-projects-static/congress/assets/staffers/2012Q1-house-disburse-detail.csv')

# %%
data_2012Q2 = pd.read_csv('https://s3.amazonaws.com/pp-projects-static/congress/assets/staffers/2012Q2-house-disburse-detail.csv')

# %%
data_2012Q3 = pd.read_csv('https://s3.amazonaws.com/pp-projects-static/congress/assets/staffers/2012Q3-house-disburse-detail.csv')

# %%
data_2012Q4 = pd.read_csv('https://s3.amazonaws.com/pp-projects-static/congress/assets/staffers/2012Q4-house-disburse-detail.csv')

# %%
data_2012=pd.concat([data_2012Q1,data_2012Q2,data_2012Q3,data_2012Q4])

# %%
data_2012
# Out:
#       BIOGUIDE_ID                 OFFICE QUARTER  \
# 0             NaN  OFFICE OF THE SPEAKER  2012Q1
# 1             NaN  OFFICE OF THE SPEAKER  2012Q1
# 2             NaN  OFFICE OF THE SPEAKER  2012Q1
# 3             NaN  OFFICE OF THE SPEAKER  2012Q1
# 4             NaN  OFFICE OF THE SPEAKER  2012Q1
# 5             NaN  OFFICE OF THE SPEAKER  2012Q1
# 6             NaN  OFFICE OF THE SPEAKER  2012Q1
# 7             NaN  OFFICE OF THE SPEAKER  2012Q1
# 8             NaN  OFFICE OF THE SPEAKER  2012Q1
# 9             NaN  OFFICE OF THE SPEAKER  2012Q1
# 10            NaN  OFFICE OF THE SPEAKER  2012Q1
# 11            NaN  OFFICE OF THE SPEAKER  2012Q1
# 12            NaN  OFFICE OF THE SPEAKER  2012Q1
# 13            NaN  OFFICE OF THE SPEAKER  2012Q1
# 14            NaN  OFFICE OF THE SPEAKER  2012Q1
# 15            NaN  OFFICE OF THE SPEAKER  2012Q1
# 16            NaN  OFFICE OF THE SPEAKER  2012Q1
# 17            NaN  OFFICE OF THE SPEAKER  2012Q1
# ...

# %%
data_2013Q1 = pd.read_csv('https://s3.amazonaws.com/pp-projects-static/congress/assets/staffers/2013Q1-house-disburse-detail.csv')

# %%
data_2013Q2 = pd.read_csv('https://s3.amazonaws.com/pp-projects-static/congress/assets/staffers/2013Q2-house-disburse-detail.csv')

# %%
data_2013Q3 = pd.read_csv('https://s3.amazonaws.com/pp-projects-static/congress/assets/staffers/2013Q3-house-disburse-detail.csv')

# %%
data_2013Q4 = pd.read_csv('https://s3.amazonaws.com/pp-projects-static/congress/assets/staffers/2013Q4-house-disburse-detail.csv')

# %%
data_2013=pd.concat([data_2013Q1,data_2013Q2,data_2013Q3,data_2013Q4])

# %%
data_2013
# Out:
#       BIOGUIDE_ID                 OFFICE QUARTER  \
# 0             NaN  OFFICE OF THE SPEAKER  2013Q1
# 1             NaN  OFFICE OF THE SPEAKER  2013Q1
# 2             NaN  OFFICE OF THE SPEAKER  2013Q1
# 3             NaN  OFFICE OF THE SPEAKER  2013Q1
# 4             NaN  OFFICE OF THE SPEAKER  2013Q1
# 5             NaN  OFFICE OF THE SPEAKER  2013Q1
# 6             NaN  OFFICE OF THE SPEAKER  2013Q1
# 7             NaN  OFFICE OF THE SPEAKER  2013Q1
# 8             NaN  OFFICE OF THE SPEAKER  2013Q1
# 9             NaN  OFFICE OF THE SPEAKER  2013Q1
# 10            NaN  OFFICE OF THE SPEAKER  2013Q1
# 11            NaN  OFFICE OF THE SPEAKER  2013Q1
# 12            NaN  OFFICE OF THE SPEAKER  2013Q1
# 13            NaN  OFFICE OF THE SPEAKER  2013Q1
# 14            NaN  OFFICE OF THE SPEAKER  2013Q1
# 15            NaN  OFFICE OF THE SPEAKER  2013Q1
# 16            NaN  OFFICE OF THE SPEAKER  2013Q1
# 17            NaN  OFFICE OF THE SPEAKER  2013Q1
# ...

# %%
data_2014Q1 = pd.read_csv('https://s3.amazonaws.com/pp-projects-static/congress/assets/staffers/2014Q1-house-disburse-detail.csv')

# %%
data_2014Q2 = pd.read_csv('https://s3.amazonaws.com/pp-projects-static/congress/assets/staffers/2014Q2-house-disburse-detail.csv')

# %%
data_2014Q3 = pd.read_csv('https://s3.amazonaws.com/pp-projects-static/congress/assets/staffers/2014Q3-house-disburse-detail.csv')

# %%
data_2014Q4 = pd.read_csv('https://s3.amazonaws.com/pp-projects-static/congress/assets/staffers/2014Q4-house-disburse-detail.csv')

# %%
data_2014=pd.concat([data_2014Q1,data_2014Q2,data_2014Q3,data_2014Q4])

# %%
data_2015Q1 = pd.read_csv('https://s3.amazonaws.com/pp-projects-static/congress/assets/staffers/2015Q1-house-disburse-detail.csv')

# %%
data_2015Q2 = pd.read_csv('https://s3.amazonaws.com/pp-projects-static/congress/assets/staffers/2015Q2-house-disburse-detail-updated.csv')

# %%
data_2015Q3 = pd.read_csv('https://s3.amazonaws.com/pp-projects-static/congress/assets/staffers/2015Q3-house-disburse-detail.csv')

# %%
data_2015Q4 = pd.read_csv('https://s3.amazonaws.com/pp-projects-static/congress/assets/staffers/2015Q4-house-disburse-detail.csv')

# %%
data_2015=pd.concat([data_2015Q1,data_2015Q2,data_2015Q3,data_2015Q4])

# %%
data_2010Q1 = pd.read_csv('https://s3.amazonaws.com/pp-projects-static/congress/assets/staffers/2010Q1-house-disburse-detail.csv',low_memory=False)

# %%
data_2010Q1.head()
# Out:
#   BIOGUIDE_ID          OFFICE QUARTER                CATEGORY  DATE  \
# 0         NaN  COMMUNICATIONS  2010Q1          OTHER SERVICES   NaN
# 1         NaN  COMMUNICATIONS  2010Q1  SUPPLIES AND MATERIALS   NaN
# 2         NaN  COMMUNICATIONS  2010Q1  SUPPLIES AND MATERIALS   NaN
# 3         NaN  COMMUNICATIONS  2010Q1  SUPPLIES AND MATERIALS   NaN
# 4         NaN  COMMUNICATIONS  2010Q1  SUPPLIES AND MATERIALS   NaN
#
#                                                PAYEE START DATE  END DATE  \
# 0  03­10       P2 MFP0003226                    W...   03/02/10  03/02/10
# 1        02­05       P2    MFP0003219       ALLSTEEL   11/28/09  11/28/09
# 2  03­05       P2    OSM42304         CDW GOVERNM...   12/21/09  12/21/09
# 3         03­05       P2    OSM42304              DO   12/21/09  12/21/09
# 4         03­05       P2    OSM42304              DO   12/21/09  12/21/09
#
#                           PURPOSE  AMOUNT              YEAR  TRANSCODE  \
# ...

# %%
data_2010=pd.concat([data_2010Q1,data_2010Q2,data_2010Q3,data_2010Q4])

# %%
data_2016Q1 = pd.read_csv('https://s3.amazonaws.com/pp-projects-static/congress/assets/staffers/2016Q1-house-disburse-detail.csv')

# %%
data_2016Q2 = pd.read_csv('https://s3.amazonaws.com/pp-projects-static/congress/assets/staffers/2016Q2-house-disburse-detail.csv')

# %%
data_2016Q3 = pd.read_csv('https://s3.amazonaws.com/pp-projects-static/congress/assets/staffers/2016Q3-house-disburse-detail.csv')

# %%
data_2016Q4 = pd.read_csv('https://s3.amazonaws.com/pp-projects-static/congress/assets/staffers/2016Q4-house-disburse-detail.csv')

# %%
data_2016=pd.concat([data_2016Q1,data_2016Q2,data_2016Q3,data_2016Q4],sort=True)

# %%
data_2016
# Out:
#       BIOGUIDE_ID                         OFFICE QUARTER  \
# 0             NaN          OFFICE OF THE SPEAKER  2016Q1
# 1             NaN          OFFICE OF THE SPEAKER  2016Q1
# 2             NaN          OFFICE OF THE SPEAKER  2016Q1
# 3             NaN          OFFICE OF THE SPEAKER  2016Q1
# 4             NaN          OFFICE OF THE SPEAKER  2016Q1
# 5             NaN          OFFICE OF THE SPEAKER  2016Q1
# 6             NaN          OFFICE OF THE SPEAKER  2016Q1
# 7             NaN          OFFICE OF THE SPEAKER  2016Q1
# 8             NaN          OFFICE OF THE SPEAKER  2016Q1
# 9             NaN          OFFICE OF THE SPEAKER  2016Q1
# 10            NaN          OFFICE OF THE SPEAKER  2016Q1
# 11            NaN          OFFICE OF THE SPEAKER  2016Q1
# 12            NaN          OFFICE OF THE SPEAKER  2016Q1
# 13            NaN          OFFICE OF THE SPEAKER  2016Q1
# 14            NaN          OFFICE OF THE SPEAKER  2016Q1
# ...

# %%
data_2017Q1 = pd.read_csv('https://s3.amazonaws.com/pp-projects-static/congress/assets/staffers/2017Q1-house-disburse-detail.csv')

# %%
data_2017Q2 = pd.read_csv('https://s3.amazonaws.com/pp-projects-static/congress/assets/staffers/2017Q2-house-disburse-detail.csv', encoding = "ISO-8859-1")

# %%
data_2017Q3 = pd.read_csv('https://s3.amazonaws.com/pp-projects-static/congress/assets/staffers/2017Q3-house-disburse-detail.csv')

# %%
data_2017Q4 = pd.read_csv('https://s3.amazonaws.com/pp-projects-static/congress/assets/staffers/2017Q4-house-disburse-detail.csv')

# %%
data_2018Q1 = pd.read_csv('https://s3.amazonaws.com/pp-projects-static/congress/assets/staffers/2018Q1-house-disburse-detail.csv',low_memory=False,encoding = "ISO-8859-1")

# %%
data_2017=pd.concat([data_2017Q1,data_2017Q2,data_2017Q3,data_2017Q4],sort=True)

# %%
data_2017
# Out:
#          AMOUNT BIOGUIDE_ID                        CATEGORY        DATE  \
# 0       19555.6         NaN          PERSONNEL COMPENSATION
# 1       26888.9         NaN          PERSONNEL COMPENSATION
# 2       23222.2         NaN          PERSONNEL COMPENSATION
# 3       40333.3         NaN          PERSONNEL COMPENSATION
# 4       12955.6         NaN          PERSONNEL COMPENSATION
# 5         33000         NaN          PERSONNEL COMPENSATION
# 6       5967.13         NaN          PERSONNEL COMPENSATION
# 7       1222.22         NaN          PERSONNEL COMPENSATION
# 8       19166.7         NaN          PERSONNEL COMPENSATION
# 9         23000         NaN          PERSONNEL COMPENSATION
# 10      42166.7         NaN          PERSONNEL COMPENSATION
# 11      41725.7         NaN          PERSONNEL COMPENSATION
# 12       9661.1         NaN          PERSONNEL COMPENSATION
# 13       346.15         NaN          PERSONNEL COMPENSATION
# ...

# %%
sum_amount2010 = data_2010.AMOUNT.str.replace(',','').astype(float).sum()

# %%
sum_amount2010
# Out:
# 1074803747.1900003

# %%
sum_amount2011 = data_2011.AMOUNT.str.replace(',','').astype(float).sum()

# %%
sum_amount2011
# Out:
# 1299889676.8899999

# %%
sum_amount2012 = data_2012.AMOUNT.str.replace(',','').astype(float).sum()

# %%
sum_amount2012
# Out:
# 1253494579.7399998

# %%
sum_amount2013 = data_2013.AMOUNT.str.replace(',','').astype(float).sum()

# %%
sum_amount2013
# Out:
# 1161832151.54

# %%
sum_amount2014 = data_2014.AMOUNT.str.replace(',','').astype(float).sum()

# %%
sum_amount2014
# Out:
# 1158971531.51

# %%
sum_amount2015 = data_2015.AMOUNT.str.replace(',','').astype(float).sum()

# %%
sum_amount2016 = data_2016.AMOUNT.str.replace(',','').astype(float).sum()

# %%
sum_amount2015
# Out:
# 1163415612.6399996

# %%
sum_amount2016
# Out:
# 881964292.6400002

# %%
data_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 413482 entries, 0 to 100152
# Data columns (total 16 columns):
# AMOUNT           413482 non-null object
# BIOGUIDE_ID      332280 non-null object
# CATEGORY         413482 non-null object
# DATE             413461 non-null object
# END DATE         413466 non-null object
# OFFICE           413482 non-null object
# PAYEE            413481 non-null object
# PROGRAM          413482 non-null object
# PURPOSE          413482 non-null object
# QUARTER          413482 non-null object
# RECIP (orig.)    103087 non-null object
# RECORDID         413482 non-null object
# SORT SEQUENCE    310395 non-null object
# START DATE       413465 non-null object
# TRANSCODE        413482 non-null object
# YEAR             307345 non-null object
# dtypes: object(16)
# memory usage: 53.6+ MB

# %%
data_2017
# Out:
#          AMOUNT BIOGUIDE_ID                        CATEGORY        DATE  \
# 0       19555.6         NaN          PERSONNEL COMPENSATION
# 1       26888.9         NaN          PERSONNEL COMPENSATION
# 2       23222.2         NaN          PERSONNEL COMPENSATION
# 3       40333.3         NaN          PERSONNEL COMPENSATION
# 4       12955.6         NaN          PERSONNEL COMPENSATION
# 5         33000         NaN          PERSONNEL COMPENSATION
# 6       5967.13         NaN          PERSONNEL COMPENSATION
# 7       1222.22         NaN          PERSONNEL COMPENSATION
# 8       19166.7         NaN          PERSONNEL COMPENSATION
# 9         23000         NaN          PERSONNEL COMPENSATION
# 10      42166.7         NaN          PERSONNEL COMPENSATION
# 11      41725.7         NaN          PERSONNEL COMPENSATION
# 12       9661.1         NaN          PERSONNEL COMPENSATION
# 13       346.15         NaN          PERSONNEL COMPENSATION
# ...

# %%
data_2017['AMOUNT']
# Out:
# 0         19555.6
# 1         26888.9
# 2         23222.2
# 3         40333.3
# 4         12955.6
# 5           33000
# 6         5967.13
# 7         1222.22
# 8         19166.7
# 9           23000
# 10        42166.7
# 11        41725.7
# 12         9661.1
# 13         346.15
# 14        12222.2
# 15           2875
# 16        24444.4
# 17        19555.6
# 18        14666.7
# 19        23222.2
# 20        17111.1
# 21        24444.4
# 22        42166.7
# 23        34222.2
# 24        9777.77
# 25         100.96
# 26          11000
# 27           64.9
# 28        9777.77
# 29         822.11
#            ...
# 100123     3681.6
# 100124      15500
# 100125      21708
# 100126     231940
# 100127     231940
# 100128     231940
# 100129    15833.4
# 100130    15833.4
# 100131    15833.4
# 100132    47500.1
# 100133    9087.71
# 100134     519995
# 100135     529083
# 100136     576583
# 100137     576583
# 100138      704.9
# 100139      704.9
# 100140      704.9
# 100141      704.9
# ...

# %%
data_2017(0,inplace=TRUE)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-137-2a65fd047086> in <module>()
# ----> 1 data_2017(0,inplace=TRUE)
#
# NameError: name 'TRUE' is not defined

# %%
data_2018Q1
# Out:
#       BIOGUIDE_ID                        OFFICE                       PROGRAM  \
# 0             NaN    2018 OFFICE OF THE SPEAKER          GENERAL EXPENDITURES
# 1         G000551    2017 HON. RAUL M. GRIJALVA  OFFICIAL EXPENSES OF MEMBERS
# 2         G000551    2017 HON. RAUL M. GRIJALVA  OFFICIAL EXPENSES OF MEMBERS
# 3         G000551    2017 HON. RAUL M. GRIJALVA  OFFICIAL EXPENSES OF MEMBERS
# 4         G000551    2017 HON. RAUL M. GRIJALVA  OFFICIAL EXPENSES OF MEMBERS
# 5         G000551    2017 HON. RAUL M. GRIJALVA  OFFICIAL EXPENSES OF MEMBERS
# 6         G000551    2017 HON. RAUL M. GRIJALVA  OFFICIAL EXPENSES OF MEMBERS
# 7         G000551    2017 HON. RAUL M. GRIJALVA  OFFICIAL EXPENSES OF MEMBERS
# 8         G000551    2017 HON. RAUL M. GRIJALVA  OFFICIAL EXPENSES OF MEMBERS
# 9         G000551    2017 HON. RAUL M. GRIJALVA  OFFICIAL EXPENSES OF MEMBERS
# 10        G000551    2017 HON. RAUL M. GRIJALVA  OFFICIAL EXPENSES OF MEMBERS
# ...

# %%
data_2018Q1.tail()
# Out:
#       BIOGUIDE_ID                   OFFICE PROGRAM   CATEGORY  \
# 77042         NaN  FISCAL YEAR 2017 PAGING  PAGING  EQUIPMENT
# 77043         NaN  FISCAL YEAR 2017 PAGING  PAGING  EQUIPMENT
# 77044         NaN  FISCAL YEAR 2017 PAGING  PAGING  EQUIPMENT
# 77045         NaN  FISCAL YEAR 2017 PAGING  PAGING  EQUIPMENT
# 77046         NaN  FISCAL YEAR 2017 PAGING  PAGING  EQUIPMENT
#
#                       SORT SEQUENCE     DATE TRANSCODE RECORDID    PAYEE  \
# 77042                        DETAIL  3/23/18        AP   980818  BEARCOM
# 77043                        DETAIL  3/23/18        AP   980819  BEARCOM
# 77044                      SUBTOTAL
# 77045                      SUBTOTAL
# 77046  GRAND TOTAL FOR ORGANIZATION
#
#       START DATE END DATE            PURPOSE    AMOUNT  YEAR
# 77042     3/1/18  3/31/18         WARRANTIES   6405.41  2018
# 77043     2/1/18  2/28/18         WARRANTIES   6405.41  2018
# 77044                      EQUIPMENT TOTALS:  25621.64  2018
# ...

# %%
data_2018Q1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77047 entries, 0 to 77046
# Data columns (total 14 columns):
# BIOGUIDE_ID      61349 non-null object
# OFFICE           77047 non-null object
# PROGRAM          77047 non-null object
# CATEGORY         77047 non-null object
# SORT SEQUENCE    77047 non-null object
# DATE             77047 non-null object
# TRANSCODE        77047 non-null object
# RECORDID         77047 non-null object
# PAYEE            77047 non-null object
# START DATE       77047 non-null object
# END DATE         77047 non-null object
# PURPOSE          77047 non-null object
# AMOUNT           77047 non-null float64
# YEAR             77047 non-null int64
# dtypes: float64(1), int64(1), object(12)
# memory usage: 8.2+ MB
